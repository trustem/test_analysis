# %%
import pandas as pd
import numpy as np
df = pd.read_csv("testdb_1000.csv")
print('Done')
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (2,3,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Done

# %%
df
# Out:
#           ID вопроса    ID ученика ID ответов  \
# 0             200336  994013092231          4
# 1             200342  994013092199          5
# 2              89593         35635          5
# 3              89598  994013117165          3
# 4              89598  994013116931          3
# 5              89598  994013117237          2
# 6              89598         36348          5
# 7              89672  994012356419          2
# 8              89672         31191          5
# 9              89672  994013117241          5
# 10             89673  994012356419          5
# 11             89673         31191          5
# 12             89673  994013116977          5
# 13             89677  994013117096          4
# 14             89677  994012537690          2
# 15             89688  994013135943          5
# 16             89713  994013117099          5
# 17             89713  994012316785          4
# 18             89713  994012638283          5
# ...

# %%
# we are droppting the rows with null values here
df = df.dropna()

# %%
# we are saving the cleared dataframe here
df.to_csv('Cleaned.csv')
